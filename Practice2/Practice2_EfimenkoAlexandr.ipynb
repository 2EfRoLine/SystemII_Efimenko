# %% [markdown]
# # Практическая работа №2
# ## Тема: «Предобработка данных в Pandas»
# ### Выполнил студент: Ефименко Александр
# #### ВАРИАНТ: 6

# %% [markdown]
# #### Задание 1. Создать Series s1 и s2 по картинке

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
import numpy as np
#импорт библиотеки

# %%
s1=pd.Series([3,2,0,1], index=['0','1','2','3'], name='apples')
s1
# Out:
# 0    3
# 1    2
# 2    0
# 3    1
# Name: apples, dtype: int64

# %%
s2=pd.Series([0,3,7,2], index=['0','1','2','3'], name='oranges')
s2
# Out:
# 0    0
# 1    3
# 2    7
# 3    2
# Name: oranges, dtype: int64

# %% [markdown]
# #### Задание 2. Создать DataFrame df1 по картинке

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pd.concat([s1,s2], axis=1)
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %% [markdown]
# # Описание DataSet
# ### Название DataSet: Car_Data
# В DataSet содержится 35000 записей об автомобилях и включает информацию марке и модели автомобиля, год производства и цвет автомобиля, расстояние, которое проехал автомобиль, стоимость автомобиля и его состояние (новый или б/у).

# %% [markdown]
# #### Задание 3. Загрузить ваш DataSet

# %%
df1=pd.read_excel("Car_Data.xlsx",sheet_name='Car_Data')

# %% [markdown]
# #### Задание 4. Показать первые 10 записей вашего DataFrame

# %%
df1.head(10)
# Out:
#    ID       Brand            Model    Year   Color   Mileage    Price  \
# 0   1       Mazda  Generic Model 3  2003.0    Blue       NaN  65732.0
# 1   2      Jaguar  Generic Model 2     NaN  Silver   89937.0  58620.0
# 2   3  Land Rover  Generic Model 2  2022.0   Green       NaN  50574.0
# 3   4     Porsche  Generic Model 2     NaN   Black   82812.0      NaN
# 4   5  Land Rover  Generic Model 3     NaN   Black       NaN  63880.0
# 5   6     Porsche  Generic Model 2  1997.0    Blue   96785.0  42794.0
# 6   7       Volvo  Generic Model 3     NaN  Silver  177385.0      NaN
# 7   8   Chevrolet  Generic Model 3  1997.0    Blue   47226.0  31079.0
# 8   9        Ford            Focus  2003.0   White  176272.0  59437.0
# 9  10     Hyundai  Generic Model 3     NaN  Silver    6153.0  27767.0
#
#   Condition
# 0       New
# 1       New
# 2       New
# 3      Used
# 4      Used
# 5       New
# 6      Used
# 7      Used
# 8      Used
# 9       New

# %% [markdown]
# #### Задание 5. Показать последние 10 записей вашего DataFrame

# %%
df1.tail(10)
# Out:
#         ID      Brand            Model    Year   Color   Mileage    Price  \
# 2141  2142        Kia  Generic Model 2  2015.0   Black   51667.0  49901.0
# 2142  2143      Mazda  Generic Model 2  2009.0   Black   81562.0  10585.0
# 2143  2144       Jeep  Generic Model 2  1996.0  Silver    3905.0  29125.0
# 2144  2145      Tesla  Generic Model 1  2006.0   Green  109420.0  34727.0
# 2145  2146     Jaguar  Generic Model 2  2005.0    Blue  120170.0  61331.0
# 2146  2147     Nissan  Generic Model 1  1993.0   Green  187396.0  21606.0
# 2147  2148       Jeep  Generic Model 2  2016.0  Silver  139505.0  56349.0
# 2148  2149        BMW  Generic Model 1  2012.0   White  188212.0  38877.0
# 2149  2150     Toyota           Tacoma  2016.0    Blue   19262.0  70938.0
# 2150  2151  Chevrolet  Generic Model 2  1994.0    Blue   63108.0  26507.0
#
#      Condition
# 2141       New
# 2142       New
# 2143      Used
# 2144       New
# 2145      Used
# 2146       New
# 2147       New
# 2148       New
# 2149      Used
# 2150      Used

# %% [markdown]
# #### Задание 6. Показать случайные 10 строк из вашего DataFrame

# %%
df1.sample(10)
# Out:
#         ID      Brand            Model    Year   Color   Mileage    Price  \
# 1642  1643        BMW  Generic Model 3  2000.0   Green   85336.0  39056.0
# 1739  1740       Ford             Edge  1996.0  Silver  107076.0  39007.0
# 985    986     Subaru  Generic Model 2  2009.0   Black   60010.0  16441.0
# 45      46     Nissan  Generic Model 1     NaN    Blue   12066.0  20581.0
# 1779  1780        BMW  Generic Model 1  2021.0     Red  101403.0  78117.0
# 1174  1175        Kia  Generic Model 1  2009.0   Green  130379.0  37610.0
# 392    393       Jeep  Generic Model 1  2007.0   Black   43541.0  49783.0
# 1662  1663  Chevrolet  Generic Model 2  1992.0   White  132287.0  64593.0
# 773    774      Lexus  Generic Model 2  2017.0     Red  124913.0  12168.0
# 2007  2008  Chevrolet  Generic Model 2  1995.0   Green  141731.0  31627.0
#
#      Condition
# 1642       New
# 1739       New
# 985        New
# 45        Used
# 1779      Used
# 1174      Used
# 392       Used
# 1662      Used
# 773        New
# 2007      Used

# %% [markdown]
# #### Задание 7. Показать типы данных для каждого столбца в DataFrame

# %%
df1.dtypes
# Out:
# ID             int64
# Brand         object
# Model         object
# Year         float64
# Color         object
# Mileage      float64
# Price        float64
# Condition     object
# dtype: object

# %% [markdown]
# #### Задание 8. Показать информацию о DataFrame, включая количество непропущенных значений, типы данных

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2151 entries, 0 to 2150
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         2151 non-null   int64
#  1   Brand      2151 non-null   object
#  2   Model      2151 non-null   object
#  3   Year       1949 non-null   float64
#  4   Color      2151 non-null   object
#  5   Mileage    1914 non-null   float64
#  6   Price      1917 non-null   float64
#  7   Condition  2151 non-null   object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 134.6+ KB

# %% [markdown]
# #### Задание 9. Показать статистический анализ числовых столбцов, включая среднее, стандартное отклонение, минимум и максимум в DataFrame

# %%
df1.describe()
# Out:
#                 ID         Year        Mileage         Price
# count  2151.000000  1949.000000    1914.000000   1917.000000
# mean   1076.000000  2005.707029   98339.449843  42697.620762
# std     621.084535     9.534109   58060.959362  21637.712281
# min       1.000000  1990.000000       5.000000   5028.000000
# 25%     538.500000  1998.000000   47499.500000  23991.000000
# 50%    1076.000000  2006.000000   98853.000000  42734.000000
# 75%    1613.500000  2014.000000  148174.000000  60891.000000
# max    2151.000000  2022.000000  199928.000000  79958.000000

# %% [markdown]
# #### Задание 10. Показать DataFrame с булевыми значениями, указывающими на пропущенные значения

# %%
df1.isna()
# Out:
#          ID  Brand  Model   Year  Color  Mileage  Price  Condition
# 0     False  False  False  False  False     True  False      False
# 1     False  False  False   True  False    False  False      False
# 2     False  False  False  False  False     True  False      False
# 3     False  False  False   True  False    False   True      False
# 4     False  False  False   True  False     True  False      False
# ...     ...    ...    ...    ...    ...      ...    ...        ...
# 2146  False  False  False  False  False    False  False      False
# 2147  False  False  False  False  False    False  False      False
# 2148  False  False  False  False  False    False  False      False
# 2149  False  False  False  False  False    False  False      False
# 2150  False  False  False  False  False    False  False      False
#
# [2151 rows x 8 columns]

# %% [markdown]
# #### Задание 11. Заменить пропущенные значения значением value в DataFrame

# %%
df1.fillna(0)
# Out:
#         ID       Brand            Model    Year   Color   Mileage    Price  \
# 0        1       Mazda  Generic Model 3  2003.0    Blue       0.0  65732.0
# 1        2      Jaguar  Generic Model 2     0.0  Silver   89937.0  58620.0
# 2        3  Land Rover  Generic Model 2  2022.0   Green       0.0  50574.0
# 3        4     Porsche  Generic Model 2     0.0   Black   82812.0      0.0
# 4        5  Land Rover  Generic Model 3     0.0   Black       0.0  63880.0
# ...    ...         ...              ...     ...     ...       ...      ...
# 2146  2147      Nissan  Generic Model 1  1993.0   Green  187396.0  21606.0
# 2147  2148        Jeep  Generic Model 2  2016.0  Silver  139505.0  56349.0
# 2148  2149         BMW  Generic Model 1  2012.0   White  188212.0  38877.0
# 2149  2150      Toyota           Tacoma  2016.0    Blue   19262.0  70938.0
# 2150  2151   Chevrolet  Generic Model 2  1994.0    Blue   63108.0  26507.0
#
#      Condition
# 0          New
# 1          New
# 2          New
# 3         Used
# 4         Used
# ...        ...
# 2146       New
# 2147       New
# 2148       New
# 2149      Used
# 2150      Used
#
# [2151 rows x 8 columns]

# %% [markdown]
# #### Задание 12. Заменить пропущенные значения значением среднего в DataFrame

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Задание 13. Заменить пропущенные значения значением медианы в DataFrame

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ссылка на файл Google Colaboratory
# https://colab.research.google.com/drive/1Ui84DQ0KBTSKQb1SMeIaqhJH9dlru7Tt#scrollTo=62hPGaNHk9Ey

# %% [markdown]
# #### Задание 14. Заменить пропущенные значения значением максимальным в DataFrame

# %%
df1.fillna(df1.max())
# Out:
#           ID       Brand            Model    Year   Color   Mileage    Price  \
# 0          1       Mazda  Generic Model 3  2003.0    Blue  199998.0  65732.0
# 1          2      Jaguar  Generic Model 2  2022.0  Silver   89937.0  58620.0
# 2          3  Land Rover  Generic Model 2  2022.0   Green  199998.0  50574.0
# 3          4     Porsche  Generic Model 2  2022.0   Black   82812.0  79999.0
# 4          5  Land Rover  Generic Model 3  2022.0   Black  199998.0  63880.0
# ...      ...         ...              ...     ...     ...       ...      ...
# 34995  34996       Mazda  Generic Model 2  2005.0     Red  186205.0  79999.0
# 34996  34997     Porsche  Generic Model 2  2022.0   Black   29735.0  71566.0
# 34997  34998       Tesla  Generic Model 3  2008.0  Silver  199998.0  38346.0
# 34998  34999         BMW  Generic Model 3  2022.0    Blue   30201.0  79999.0
# 34999  35000        Jeep  Generic Model 2  2022.0    Blue  154016.0  50726.0
#
#       Condition
# 0           New
# 1           New
# 2           New
# 3          Used
# 4          Used
# ...         ...
# 34995      Used
# 34996       New
# 34997      Used
# 34998       New
# 34999      Used
#
# [35000 rows x 8 columns]

# %% [markdown]
# #### Задание 15. Заменить пропущенные значения значением минимальным в DataFrame

# %%
df1.fillna(df1.min())
# Out:
#           ID       Brand            Model    Year   Color   Mileage    Price  \
# 0          1       Mazda  Generic Model 3  2003.0    Blue       4.0  65732.0
# 1          2      Jaguar  Generic Model 2  1990.0  Silver   89937.0  58620.0
# 2          3  Land Rover  Generic Model 2  2022.0   Green       4.0  50574.0
# 3          4     Porsche  Generic Model 2  1990.0   Black   82812.0   5005.0
# 4          5  Land Rover  Generic Model 3  1990.0   Black       4.0  63880.0
# ...      ...         ...              ...     ...     ...       ...      ...
# 34995  34996       Mazda  Generic Model 2  2005.0     Red  186205.0   5005.0
# 34996  34997     Porsche  Generic Model 2  1990.0   Black   29735.0  71566.0
# 34997  34998       Tesla  Generic Model 3  2008.0  Silver       4.0  38346.0
# 34998  34999         BMW  Generic Model 3  1990.0    Blue   30201.0   5005.0
# 34999  35000        Jeep  Generic Model 2  2022.0    Blue  154016.0  50726.0
#
#       Condition
# 0           New
# 1           New
# 2           New
# 3          Used
# 4          Used
# ...         ...
# 34995      Used
# 34996       New
# 34997      Used
# 34998       New
# 34999      Used
#
# [35000 rows x 8 columns]

# %% [markdown]
# #### Задание 16. Показать количество уникальных значений в каждом столбце в DataFrame

# %%
df1.nunique()
# Out:
# ID           2151
# Brand          20
# Model          21
# Year           33
# Color           6
# Mileage      1908
# Price        1891
# Condition       2
# dtype: int64

# %% [markdown]
# #### Задание 17. Подсчитать количество вхождений каждого уникального значения в столбце в DataFrame

# %%
df1.value_counts(subset="Brand")
# Out:
# Brand
# Volvo            131
# Jeep             118
# BMW              118
# Lexus            118
# Audi             117
# Mazda            114
# Jaguar           111
# Chevrolet        109
# Mercedes-Benz    108
# Subaru           108
# Ford             107
# Tesla            107
# Volkswagen       106
# Nissan           105
# Land Rover        99
# Toyota            98
# Kia               97
# Porsche           97
# Honda             92
# Hyundai           91
# Name: count, dtype: int64

# %% [markdown]
# #### Задание 18. Удалить строки с пропущенными значениями в DataFrame

# %%
df1.dropna()
# Out:
#         ID      Brand            Model    Year   Color   Mileage    Price  \
# 5        6    Porsche  Generic Model 2  1997.0    Blue   96785.0  42794.0
# 7        8  Chevrolet  Generic Model 3  1997.0    Blue   47226.0  31079.0
# 8        9       Ford            Focus  2003.0   White  176272.0  59437.0
# 13      14      Lexus  Generic Model 2  1998.0     Red   56308.0  53734.0
# 14      15  Chevrolet  Generic Model 3  1992.0     Red   47196.0  21061.0
# ...    ...        ...              ...     ...     ...       ...      ...
# 2146  2147     Nissan  Generic Model 1  1993.0   Green  187396.0  21606.0
# 2147  2148       Jeep  Generic Model 2  2016.0  Silver  139505.0  56349.0
# 2148  2149        BMW  Generic Model 1  2012.0   White  188212.0  38877.0
# 2149  2150     Toyota           Tacoma  2016.0    Blue   19262.0  70938.0
# 2150  2151  Chevrolet  Generic Model 2  1994.0    Blue   63108.0  26507.0
#
#      Condition
# 5          New
# 7         Used
# 8         Used
# 13        Used
# 14        Used
# ...        ...
# 2146       New
# 2147       New
# 2148       New
# 2149      Used
# 2150      Used
#
# [1703 rows x 8 columns]

# %% [markdown]
# #### Задание 19. Показать булевы значения, указывающие на дубликаты строк в DataFrame

# %%
df1.duplicated(subset="Brand")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 2146     True
# 2147     True
# 2148     True
# 2149     True
# 2150     True
# Length: 2151, dtype: bool

# %% [markdown]
# #### Задание 20. Удалить дубликаты строк из DataFrame

# %%
df1.drop_duplicates()
# Out:
#         ID       Brand            Model    Year   Color   Mileage    Price  \
# 0        1       Mazda  Generic Model 3  2003.0    Blue       NaN  65732.0
# 1        2      Jaguar  Generic Model 2     NaN  Silver   89937.0  58620.0
# 2        3  Land Rover  Generic Model 2  2022.0   Green       NaN  50574.0
# 3        4     Porsche  Generic Model 2     NaN   Black   82812.0      NaN
# 4        5  Land Rover  Generic Model 3     NaN   Black       NaN  63880.0
# ...    ...         ...              ...     ...     ...       ...      ...
# 2146  2147      Nissan  Generic Model 1  1993.0   Green  187396.0  21606.0
# 2147  2148        Jeep  Generic Model 2  2016.0  Silver  139505.0  56349.0
# 2148  2149         BMW  Generic Model 1  2012.0   White  188212.0  38877.0
# 2149  2150      Toyota           Tacoma  2016.0    Blue   19262.0  70938.0
# 2150  2151   Chevrolet  Generic Model 2  1994.0    Blue   63108.0  26507.0
#
#      Condition
# 0          New
# 1          New
# 2          New
# 3         Used
# 4         Used
# ...        ...
# 2146       New
# 2147       New
# 2148       New
# 2149      Used
# 2150      Used
#
# [2151 rows x 8 columns]

# %% [markdown]
# #### Задание 21. Заменить определенные значения в DataFrame на указанные значения

# %%
df1.replace("Used", 1)
# Out:
#         ID       Brand            Model    Year   Color   Mileage    Price  \
# 0        1       Mazda  Generic Model 3  2003.0    Blue       NaN  65732.0
# 1        2      Jaguar  Generic Model 2     NaN  Silver   89937.0  58620.0
# 2        3  Land Rover  Generic Model 2  2022.0   Green       NaN  50574.0
# 3        4     Porsche  Generic Model 2     NaN   Black   82812.0      NaN
# 4        5  Land Rover  Generic Model 3     NaN   Black       NaN  63880.0
# ...    ...         ...              ...     ...     ...       ...      ...
# 2146  2147      Nissan  Generic Model 1  1993.0   Green  187396.0  21606.0
# 2147  2148        Jeep  Generic Model 2  2016.0  Silver  139505.0  56349.0
# 2148  2149         BMW  Generic Model 1  2012.0   White  188212.0  38877.0
# 2149  2150      Toyota           Tacoma  2016.0    Blue   19262.0  70938.0
# 2150  2151   Chevrolet  Generic Model 2  1994.0    Blue   63108.0  26507.0
#
#      Condition
# 0          New
# 1          New
# 2          New
# 3            1
# 4            1
# ...        ...
# 2146       New
# 2147       New
# 2148       New
# 2149         1
# 2150         1
#
# [2151 rows x 8 columns]

# %% [markdown]
# #### Задание 22. Сохранить DataFrame в формат Excel с именем Practice2_dataset.xlsx

# %%
df1.to_excel("Practice2_dataset.xlsx")

# %% [markdown]
# #### Задание 23. Сохранить DataFrame в формат CSV с именем Practice2_ dataset.CSV

# %%
df1.to_csv("Practice2_dataset.csv")

# %% [markdown]
# #### Задание 24. Сохранить DataFrame в формат JSON с именем Practice2_ dataset.json

# %%
df1.to_json("Practice2_dataset.json")
