# %% [markdown]
# # Практическая работа №3
# ## Тема: «Визуализация данных»
# ### Выполнил студент: Ефименко Александр
# #### ВАРИАНТ: 6

# %%
#Вся необходимая теория находится в файле Devpractice Team. Библиотека Matplotlib.pdf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math
import numpy as np

# %% [markdown]
# #### Задание 1. Загрузить данные из файла Dataset_Variants.xlsx, где номер листа ваш вариант

# %%
df = pd.read_excel("Dataset_Variants.xlsx",sheet_name='6')

# %% [markdown]
# #### Задание 2. Отобразить данные вашего варианта

# %%
print("Данные 6 варианта")
df
# Out:
# Данные 6 варианта
#      X           Y
# 0    1   66.553201
# 1    2   36.462115
# 2    3   39.599274
# 3    4  -43.714084
# 4    5   31.700739
# 5    6   57.409824
# 6    7   40.962777
# 7    8   63.398562
# 8    9   17.901545
# 9   10  -56.134030
# 10  11   76.564521
# 11  12  120.991518
# 12  13   43.830500
# 13  14   97.769618
# 14  15   69.797483
# 15  16  -62.475823
# 16  17   27.482503
# 17  18   65.689096
# 18  19   70.783830
# 19  20   14.476956
# 20  21   58.843529
# 21  22   61.308600
# 22  23   24.865148
# 23  24   10.050786
# 24  25   16.344262
# 25  26   25.007370
# 26  27  -79.751959
# 27  28   44.759008
# 28  29   62.164890
# 29  30   46.435577
# 30  31  -31.633152
# 31  32   33.073479
# 32  33   31.758208
# 33  34   35.936483
# 34  35   29.820757
# 35  36   47.462595
# 36  37    5.859039
# 37  38   24.571722
# 38  39   33.880087
# 39  40  -98.858510
# 40  41   30.947393
# 41  42   70.171285
# 42  43   68.331775
# 43  44   58.520544
# 44  45   40.651759
# 45  46   46.151303
# 46  47   54.430348
# 47  48  -37.541486
# 48  49   75.547251
# 49  50   50.123350

# %% [markdown]
# #### Задание 3. Визуализировать данные в стиле Столбчатые диаграммы (подписать оси)

# %%
# %matplotlib inline
X = df["X"]
Y = df["Y"]
plt.bar(X, Y)
plt.title("Столбчатая диаграмма!")
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# #### Задание 4. Визуализировать данные в стиле Точечный график (подписать оси)

# %%
plt.scatter(X,Y)
plt.title("Точечный график!")
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# #### Задание 5. Отрицательные значение по Y заменить значением по модулю

# %%
df_new = df["Y"].abs()

# %% [markdown]
# #### Задание 6. Отобразить изменённые данные вашего варианта

# %%
df_new
# Out:
# 0      66.553201
# 1      36.462115
# 2      39.599274
# 3      43.714084
# 4      31.700739
# 5      57.409824
# 6      40.962777
# 7      63.398562
# 8      17.901545
# 9      56.134030
# 10     76.564521
# 11    120.991518
# 12     43.830500
# 13     97.769618
# 14     69.797483
# 15     62.475823
# 16     27.482503
# 17     65.689096
# 18     70.783830
# 19     14.476956
# 20     58.843529
# 21     61.308600
# 22     24.865148
# 23     10.050786
# 24     16.344262
# 25     25.007370
# 26     79.751959
# 27     44.759008
# 28     62.164890
# 29     46.435577
# 30     31.633152
# 31     33.073479
# 32     31.758208
# 33     35.936483
# 34     29.820757
# 35     47.462595
# 36      5.859039
# 37     24.571722
# 38     33.880087
# 39     98.858510
# 40     30.947393
# 41     70.171285
# 42     68.331775
# 43     58.520544
# 44     40.651759
# 45     46.151303
# 46     54.430348
# 47     37.541486
# 48     75.547251
# 49     50.123350
# Name: Y, dtype: float64

# %% [markdown]
# #### Задание 7. Визуализировать изменённые данные вашего варианта в стиле Столбчатые диаграммы (подписать оси, столбцы зеленого цвета)

# %%
# %matplotlib inline
X_new = df["X"]
plt.figure(facecolor = "green") 
plt.bar(X_new, df_new, color="green")
plt.title("Столбчатая диаграмма!")
plt.xlabel("X")
plt.ylabel("Значения Y")
# Out:
# Text(0, 0.5, 'Значения Y')

# %% [markdown]
# #### Задание 8. Визуализировать изменённые данные вашего варианта в стиле Точечный график (подписать оси, точки зеленого цвета)

# %%
plt.figure(facecolor = "green") 
plt.scatter(X_new, df_new, color="green")
plt.title("Точечный график!")
plt.xlabel("X")
plt.ylabel("Значения Y")
# Out:
# Text(0, 0.5, 'Значения Y')

# %% [markdown]
# #### Задание 9. Визуализировать изменённые данные вашего варианта в стиле Линейный график (подписать оси, цвет, стиль линии изменить на ваше усмотрение)

# %%
plt.figure(facecolor = "green")
plt.plot(X_new, df_new, '--', color="green")
plt.title("Линейный график!")
plt.xlabel("X")
plt.ylabel("Значения Y")
# Out:
# Text(0, 0.5, 'Значения Y')

# %% [markdown]
# #### Задание 10. Визуализировать изменённые данные вашего варианта в стиле Линейный график с маркером (подписать оси, цвет, стиль линии и тип маркера изменить на ваше усмотрение)

# %%
plt.figure(facecolor = "purple")
plt.plot(X_new, df_new, 'o--', color="purple")
plt.title("Линейный график!")
plt.xlabel("X")
plt.ylabel("Значения Y")
# Out:
# Text(0, 0.5, 'Значения Y')

# %% [markdown]
# #### Задание 11. Визуализировать изменённые данные вашего варианта в стиле Цветовое распределение

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_new, bins=30, kde=True, color='blue')
plt.title('Цветовое распределение значений Y')
plt.xlabel('Значения Y')
plt.ylabel('Частота')
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# #### Задание 12. Загрузить данные из файла Dataset_Variants.xlsx c номером листа 10000, где номер столбца Y ваш вариант

# %%
df10000 = pd.read_excel("Dataset_Variants.xlsx",sheet_name='10000')

# %% [markdown]
# #### Задание 13. Отобразить данные вашего варианта

# %%
df10000["Y6"]
# Out:
# 0       1024.097631
# 1        999.513250
# 2       1018.881735
# 3       1022.765335
# 4       1007.198253
#            ...
# 9995    1034.960067
# 9996     988.197658
# 9997    1006.412307
# 9998     999.002398
# 9999    1028.559043
# Name: Y6, Length: 10000, dtype: float64

# %% [markdown]
# #### Задание 14. Визуализировать данные в стиле Столбчатые диаграммы (подписать оси)

# %%
# %matplotlib inline
X10000 = df10000["X"]
Y10000 = df10000["Y6"]
plt.bar(X10000, Y10000)
plt.title("Столбчатая диаграмма!")
plt.xlabel("X")
plt.ylabel("Значения Y6")
# Out:
# Text(0, 0.5, 'Значения Y6')

# %% [markdown]
# #### Задание 15. Визуализировать данные в стиле Точечный график (подписать оси)

# %%
plt.scatter(X10000,Y10000)
plt.title("Точечный график!")
plt.xlabel("X")
plt.ylabel("Значения Y6")
# Out:
# Text(0, 0.5, 'Значения Y6')

# %% [markdown]
# #### Задание 16. Визуализировать данные вашего варианта в стиле Столбчатые диаграммы (подписать оси, столбцы зеленого цвета)

# %%
plt.bar(X10000, Y10000, color="green")
plt.title("Столбчатая диаграмма!")
plt.xlabel("X")
plt.ylabel("Значения Y6")
# Out:
# Text(0, 0.5, 'Значения Y6')

# %% [markdown]
# #### Задание 17. Визуализировать данные вашего варианта в стиле Точечный график (подписать оси, столбцы красного цвета)

# %%
plt.scatter(X10000,Y10000, color="red")
plt.title("Точечный график!")
plt.xlabel("X")
plt.ylabel("Значения Y6")
# Out:
# Text(0, 0.5, 'Значения Y6')

# %% [markdown]
# #### Задание 18. Визуализировать данные вашего варианта в стиле Линейный график (подписать оси, цвет, стиль линии изменить на ваше усмотрение)

# %%
plt.plot(X10000,Y10000, '--', color="green")
plt.title("Линейный график!")
plt.xlabel("X")
plt.ylabel("Значения Y6")
# Out:
# Text(0, 0.5, 'Значения Y6')

# %% [markdown]
# #### Задание 19. Визуализировать данные вашего варианта в стиле Цветовое распределение

# %%
plt.figure(figsize=(10, 6))
sns.histplot(Y10000, bins=30, kde=True, color='blue')
plt.title('Цветовое распределение значений Y')
plt.xlabel('Значения Y')
plt.ylabel('Частота')
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# #### Задание 20. Загрузить данные из вашего скаченного DataSet

# %%
df_my = pd.read_excel("My_DataSet(Super_Racing).xlsx",sheet_name='1')

# %% [markdown]
# #### Задание 21. Отобразить данные вашего скаченного DataSet

# %%
df_my
# Out:
#     ID                 Name_Cards        Quality  0-100 (sec)  Power (l.s.)  \
# 0    0        Alfa Romeo Montreal        Обычная          7.2         200.0
# 1    1       Экстренная остановка          Бонус          NaN           NaN
# 2    2          Alfa Romeo Spider        Обычная          7.2         264.0
# 3    3            Audi A4 Allroad        Обычная          6.9         211.0
# 4    4                BMW 3.0 CSL        Обычная          7.3         206.0
# 5    5            BMW Z4 Roadster        Обычная          4.8         340.0
# 6    6             Cadillac CTS-V        Обычная          3.9         556.0
# 7    7           Chevrolet Camaro   Супер-редкая          4.8         426.0
# 8    8     Mercedes-Benz R63L AMG        Обычная          5.1         510.0
# 9    9                   DeLorean        Обычная          9.6        1130.0
# 10  10               Крутой спуск          Бонус          NaN           NaN
# 11  11                  Ford GT40        Обычная          4.3         485.0
# 12  12           Ford Focus RS500        Обычная          5.6         350.0
# 13  13                Honda NSX-R        Обычная          4.6         280.0
# 14  14                 Jaguar XFR        Обычная          4.9         510.0
# 15  15              Jeep Cherokee        Обычная         10.7         205.0
# 16  16             Koenigsegg CCX        Обычная          3.2         806.0
# 17  17         Chevrolet Suburban        Обычная          8.7         320.0
# 18  18                Marussia B2        Обычная          5.0         300.0
# 19  19     Mercedes-Benz C 63 AMG        Обычная          4.5         457.0
# 20  20  Mercedes-Benz CLK DTM AMG        Обычная          3.8         592.0
# 21  21             Новые покрышки          Бонус          NaN           NaN
# 22  22            Panoz Esperante        Обычная          5.1         305.0
# 23  23                Porsche 968        Обычная          6.5         240.0
# 24  24                   Светофор          Бонус          NaN           NaN
# 25  25          Seat Leon Cupra R         Редкая          6.2         265.0
# 26  26   Spyker C8 Aileron Spyder         Редкая          4.5         400.0
# 27  27        Suzuki Grand Vitara        Обычная         14.4         233.0
# 28  28        Volkswagen Golf GTI        Обычная          6.7         210.0
# 29  29         Volkswagen Phaeton        Обычная          6.1         444.0
# 30  30                  Zenvo ST1   Супер-редкая          3.0        1104.0
# 31  31          Alfa Romeo Spider        Обычная         13.2         110.0
# 32  32       Alfa Romeo 8C Spider         Редкая          4.5         456.0
# 33  33     Cadillac SRX Crossover        Обычная          8.2         265.0
# 34  34                Audi R8 V10         Редкая          3.9         525.0
# 35  35               BMW M3 Coupe        Обычная          4.8         420.0
# 36  36          Bristol Fighter T        Обычная          3.5        1026.0
# 37  37            Caterham CSR260        Обычная          3.1         260.0
# 38  38         Chevrolet Traverse        Обычная          8.6         288.0
# 39  39          De Tomaso Pantera   Супер-редкая          5.5         330.0
# 40  40             Классная песня          Бонус          NaN           NaN
# 41  41            Ford Mustang GT        Обычная          4.7         412.0
# 42  42               Ginetta F400        Обычная          3.7         415.0
# 43  43                 Honda CR-Z        Обычная         10.2         124.0
# 44  44               Jaguar XK150        Обычная          7.6         265.0
# 45  45             Koenigsegg CCR  Ультра-редкая          3.2         817.0
# 46  46               Lexus RX450h        Обычная          7.8         300.0
# 47  47   Chrysler Crossfire SRT-6        Обычная          4.8         330.0
# 48  48                Maybach 62S        Обычная          5.1         612.0
# 49  49      Morgan Roadster Sport        Обычная          4.9         223.0
# 50  50    Pagani Zonda Roadster F   Супер-редкая          3.6         650.0
# 51  51      Porsche Cayenne Turbo   Супер-редкая          4.7         500.0
# 52  52  Rolls-Royce Phantom Coupe         Редкая          5.8         460.0
# 53  53      Перевёрнутый грузовик          Бонус          NaN           NaN
# 54  54              Tesla Model S   Супер-редкая          5.6         402.0
# 55  55            Wiesmann GT MF4        Обычная          4.6         367.0
# 56  56       Неправильный поворот          Бонус          NaN           NaN
# 57  57     Aston Martin DB4 Coupe        Обычная          9.3         240.0
# 58  58             Alfa Romeo 159        Обычная          7.0         260.0
# 59  59        Aston Martin Rapide        Обычная          5.2         477.0
#
#     Max_Speed (km/h)  Engine_Capacity (sm3)  Weight (kg)   Cost (S)
# 0              224.0                 2593.0       1270.0     7300.0
# 1                NaN                    NaN          NaN        NaN
# 2              245.0                 3196.0       1685.0    53800.0
# 3              232.0                 1984.0       1650.0    48800.0
# 4              217.0                 3003.0       1270.0     9500.0
# 5              250.0                 2979.0       1580.0    95000.0
# 6              307.0                 6162.0       1930.0    63000.0
# 7              250.0                 6162.0       1755.0    33900.0
# 8              250.0                 6208.0       2375.0   115400.0
# 9              209.0                 2849.0       1244.0    16000.0
# 10               NaN                    NaN          NaN        NaN
# 11             330.0                 6997.0       1046.0    16000.0
# 12             265.0                 2522.0       1467.0    53000.0
# 13             280.0                 3179.0       1270.0    96300.0
# 14             250.0                 5000.0       1891.0    80000.0
# 15             193.0                 3701.0       1935.0    96900.0
# 16             395.0                 4700.0       1280.0   102000.0
# 17             158.0                 5328.0       2652.0    96500.0
# 18             250.0                 3498.0       1100.0   150000.0
# 19             250.0                 6208.0       1780.0    60300.0
# 20             322.0                 5439.0       1748.0   306700.0
# 21               NaN                    NaN          NaN        NaN
# 22             250.0                 4601.0       1536.0    65000.0
# 23             252.0                 2990.0       1370.0    54500.0
# 24               NaN                    NaN          NaN        NaN
# 25             250.0                 1984.0       1450.0    40200.0
# 26             300.0                 4172.0       1425.0   104000.0
# 27             200.0                 1386.0       1753.0    29000.0
# 28             240.0                 1984.0       1318.0    36000.0
# 29             250.0                 5998.0       2449.0   116000.0
# 30             375.0                 7000.0       1376.0  1100000.0
# 31             180.0                 1570.0        990.0     2600.0
# 32             291.0                 4691.0       1675.0   256000.0
# 33             209.0                 2986.0       2050.0    48000.0
# 34             316.0                 5204.0       1620.0   146000.0
# 35             250.0                 3999.0       1655.0   100000.0
# 36             362.0                 7994.0       1595.0   830000.0
# 37             250.0                 2261.0        575.0    62200.0
# 38             182.0                 3564.0       2298.0    40000.0
# 39             256.0                 5763.0       1417.0    50000.0
# 40               NaN                    NaN          NaN        NaN
# 41             240.0                 4951.0       1639.0    26000.0
# 42             298.0                 3000.0       1046.0   133000.0
# 43             200.0                 1497.0       1198.0    28200.0
# 44             222.0                 3781.0       1346.0     4700.0
# 45             388.0                 4700.0       1230.0   544000.0
# 46             200.0                 3456.0       2700.0    77000.0
# 47             250.0                 3199.0       1460.0    45600.0
# 48             250.0                 5980.0       2855.0   456500.0
# 49             215.0                 2967.0        938.0    54000.0
# 50             344.0                 7291.0       1230.0   781000.0
# 51             278.0                 4806.0       2170.0   104800.0
# 52             250.0                 6749.0       2665.0   408000.0
# 53               NaN                    NaN          NaN        NaN
# 54             193.0                    NaN       1818.0    56000.0
# 55             291.0                 4799.0       1280.0   164000.0
# 56               NaN                    NaN          NaN        NaN
# 57             224.0                 3670.0       1308.0     9770.0
# 58             240.0                 3195.0       1480.0    41000.0
# 59             296.0                 5935.0       1950.0   199900.0

# %% [markdown]
# #### Задание 22. Визуализировать данные вашего скаченного DataSet в стиле Столбчатые диаграммы (подписать оси, заголовок)

# %%
plt.figure(facecolor = "blue") 
X1 = df_my["ID"]
Y1 = df_my["Max_Speed (km/h)"]
plt.bar(X1, Y1)
plt.title("Столбчатая диаграмма (Max_Speed)")
plt.xlabel("X")
plt.ylabel("Значения km/h")
# Out:
# Text(0, 0.5, 'Значения km/h')

# %% [markdown]
# #### Задание 23. Визуализировать данные вашего скаченного DataSet в стиле Точечный график (подписать оси, заголовок)

# %%
X_ls = df_my["Power (l.s.)"]
Y_kmh = df_my["Max_Speed (km/h)"]
plt.figure(facecolor = "blue") 
plt.scatter(X_ls,Y_kmh)
plt.grid(True)
plt.title("Точечный график (взаимосвязь между мощностью и макс. скоростью)")
plt.xlabel("l.s.")
plt.ylabel("km/h")
# Out:
# Text(0, 0.5, 'km/h')

# %% [markdown]
# #### Задание 24. Визуализировать данные вашего скаченного DataSet в стиле Столбчатые диаграммы (подписать оси, заголовок, столбцы зеленого цвета)

# %%
plt.figure(facecolor = "blue") 
X1 = df_my["ID"]
Y_kg = df_my["Weight (kg)"]
plt.bar(X1, Y_kg)
plt.title("Столбчатая диаграмма (Weight))")
plt.xlabel("X")
plt.ylabel("Значения kg")
# Out:
# Text(0, 0.5, 'Значения kg')

# %% [markdown]
# #### Задание 25. Визуализировать изменённые данные вашего варианта в стиле Точечный график (подписать оси, заголовок, точки красного цвета)

# %%
X_ls = df_my["Power (l.s.)"]
Y_kmh = df_my["Max_Speed (km/h)"]
plt.figure(facecolor = "red") 
plt.scatter(X_ls,Y_kmh, color="red")
plt.grid(True)
plt.title("Точечный график (взаимосвязь между мощностью и макс. скоростью)")
plt.xlabel("l.s.")
plt.ylabel("km/h")
# Out:
# Text(0, 0.5, 'km/h')

# %% [markdown]
# #### Задание 26. Визуализировать данные вашего скаченного DataSet в стиле Линейный график (подписать оси, заголовок, цвет, стиль линии изменить на ваше усмотрение)

# %%
X1 = df_my["ID"]
Y_sm = df_my["Engine_Capacity (sm3)"]
plt.figure(facecolor = "green") 
plt.plot(X1,Y_sm, 'o--', color="black")
plt.title("Линейный график (Engine_Capacity)")
plt.xlabel("X")
plt.ylabel("Значения sm3")
# Out:
# Text(0, 0.5, 'Значения sm3')

# %% [markdown]
# #### Задание 27. Визуализировать данные вашего скаченного DataSet в стиле Цветовое распределение

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_my["Max_Speed (km/h)"], bins=30, kde=True, color='blue')
plt.title('Цветовое распределение значений Y')
plt.xlabel('Значения Y')
plt.ylabel('Частота')
# Out:
# Text(0, 0.5, 'Частота')
